# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/SDC-Data science/Data Model - Pizza Sales.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-44857e244d59> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/drive/MyDrive/SDC-Data science/Data Model - Pizza Sales.csv")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(10)
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
# 5                 6         2     thai_ckn_l         1   1/1/2015   11:57:40
# 6                 7         3    ital_supr_m         1   1/1/2015   12:12:28
# 7                 8         3   prsc_argla_l         1   1/1/2015   12:12:28
# 8                 9         4    ital_supr_m         1   1/1/2015   12:16:31
# 9                10         5    ital_supr_m         1   1/1/2015   12:21:30
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# ...

# %%
type(df['unit_prictype(df['Age'])e'])
# Out:
# pandas.core.series.Series

# %%
df['unit_price']
# Out:
# 0        13.25
# 1        16.00
# 2        18.50
# 3        20.75
# 4        16.00
#          ...
# 48615    16.75
# 48616    17.95
# 48617    12.00
# 48618    20.25
# 48619    12.75
# Name: unit_price, Length: 48620, dtype: float64

# %%
df['unit_price'].shape
# Out:
# (48620,)

# %%
df[['unit_price','total_price',]]
# Out:
#        unit_price  total_price
# 0           13.25        13.25
# 1           16.00        16.00
# 2           18.50        18.50
# 3           20.75        20.75
# 4           16.00        16.00
# ...           ...          ...
# 48615       16.75        16.75
# 48616       17.95        17.95
# 48617       12.00        12.00
# 48618       20.25        20.25
# 48619       12.75        12.75
#
# [48620 rows x 2 columns]

# %%
type(df[['unit_price','total_price']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['unit_price','total_price']].shape
# Out:
# (48620, 2)

# %%
df.iloc[0]
# Out:
# order_details_id                                            1
# order_id                                                    1
# pizza_id                                           hawaiian_m
# quantity                                                    1
# order_date                                           1/1/2015
# order_time                                           11:38:36
# unit_price                                              13.25
# total_price                                             13.25
# pizza_size                                                  M
# pizza_category                                        Classic
# pizza_ingredients    Sliced Ham, Pineapple, Mozzarella Cheese
# pizza_name                                 The Hawaiian Pizza
# Name: 0, dtype: object

# %%
df.iloc[1:5]
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# ...

# %%
type(df.iloc[0:3])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[1:4].shape
# Out:
# (3, 12)

# %%
df['pizza_category']=='Classic'
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617     True
# 48618    False
# 48619    False
# Name: pizza_category, Length: 48620, dtype: bool

# %%
def get_ChestPain_count(pizza_category):
    mask=df['pizza_category']==pizza_category
    return df[mask].shape[0]

# %%
mask1=df['pizza_category']=='Classic'
mask2=df['unit_price']>30


df[mask1 & mask2]
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 3447               3448      1528  the_greek_xxl         1   1/26/2015
# 3563               3564      1581  the_greek_xxl         1   1/27/2015
# 5901               5902      2614  the_greek_xxl         1   2/13/2015
# 6365               6366      2813  the_greek_xxl         1   2/16/2015
# 7490               7491      3297  the_greek_xxl         1   2/25/2015
# 9844               9845      4307  the_greek_xxl         1   3/14/2015
# 10282             10283      4498  the_greek_xxl         1   3/17/2015
# 10875             10876      4761  the_greek_xxl         1   3/21/2015
# 13511             13512      5927  the_greek_xxl         1   4/10/2015
# 13779             13780      6038  the_greek_xxl         1   4/12/2015
# 14029             14030      6150  the_greek_xxl         1   4/13/2015
# 15330             15331      6724  the_greek_xxl         1   4/23/2015
# ...

# %%
df[mask1 & mask2].shape[0]
# Out:
# 28

# %%
df['pizza_size'].value_counts()
# Out:
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: pizza_size, dtype: int64

# %%
import matplotlib.pyplot as plt


df['total_price'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['unit_price'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
df['pizza_name'].value_counts()
# Out:
# The Classic Deluxe Pizza                      2416
# The Barbecue Chicken Pizza                    2372
# The Hawaiian Pizza                            2370
# The Pepperoni Pizza                           2369
# The Thai Chicken Pizza                        2315
# The California Chicken Pizza                  2302
# The Sicilian Pizza                            1887
# The Spicy Italian Pizza                       1887
# The Southwest Chicken Pizza                   1885
# The Four Cheese Pizza                         1850
# The Italian Supreme Pizza                     1849
# The Big Meat Pizza                            1811
# The Vegetables + Vegetables Pizza             1510
# The Mexicana Pizza                            1456
# The Napolitana Pizza                          1451
# The Spinach and Feta Pizza                    1432
# The Prosciutto and Arugula Pizza              1428
# The Pepper Salami Pizza                       1422
# ...

# %%
df['pizza_name'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='pizza_name'>

# %%
df['pizza_category'].value_counts()
# Out:
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: pizza_category, dtype: int64

# %%
df['pizza_size'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='pizza_size'>

# %%
type(df['pizza_category'].value_counts())
# Out:
# pandas.core.series.Series

# %%
type(df['unit_price'].value_counts())
# Out:
# pandas.core.series.Series

# %%
series1=df['unit_price'].value_counts()
series1
# Out:
# 20.75    8685
# 12.00    5600
# 16.00    4474
# 16.75    4294
# 16.50    4040
# 12.50    3328
# 20.25    3032
# 12.75    2507
# 20.50    1998
# 18.50    1359
# 17.95    1273
# 16.25    1114
# 10.50    1001
# 12.25     830
# 9.75      739
# 15.25     712
# 14.75     577
# 11.00     570
# 25.50     544
# 23.65     480
# 13.25     473
# 14.50     391
# 17.50     381
# 21.00     190
# 35.95      28
# Name: unit_price, dtype: int64

# %%
series1.index
# Out:
# Float64Index([20.75,  12.0,  16.0, 16.75,  16.5,  12.5, 20.25, 12.75,  20.5,
#                18.5, 17.95, 16.25,  10.5, 12.25,  9.75, 15.25, 14.75,  11.0,
#                25.5, 23.65, 13.25,  14.5,  17.5,  21.0, 35.95],
#              dtype='float64')

# %%
series1.values
# Out:
# array([8685, 5600, 4474, 4294, 4040, 3328, 3032, 2507, 1998, 1359, 1273,
#        1114, 1001,  830,  739,  712,  577,  570,  544,  480,  473,  391,
#         381,  190,   28])

# %%
df['unit_pricme'].value_counts()
# Out:
# 20.75    8685
# 12.00    5600
# 16.00    4474
# 16.75    4294
# 16.50    4040
# 12.50    3328
# 20.25    3032
# 12.75    2507
# 20.50    1998
# 18.50    1359
# 17.95    1273
# 16.25    1114
# 10.50    1001
# 12.25     830
# 9.75      739
# 15.25     712
# 14.75     577
# 11.00     570
# 25.50     544
# 23.65     480
# 13.25     473
# 14.50     391
# 17.50     381
# 21.00     190
# 35.95      28
# Name: unit_price, dtype: int64

# %%
df['unit_price'].sort_values(ascending=False)
# Out:
# 22903    35.95
# 13779    35.95
# 5901     35.95
# 14029    35.95
# 41182    35.95
#          ...
# 39654     9.75
# 2252      9.75
# 46395     9.75
# 35242     9.75
# 3771      9.75
# Name: unit_price, Length: 48620, dtype: float64

# %%
df.sort_values('total_price')
# Out:
#        order_details_id  order_id      pizza_id  quantity  order_date  \
# 35630             35631     15728   pepperoni_s         1   9/20/2015
# 20509             20510      9006   pepperoni_s         1   5/31/2015
# 1563               1564       699   pepperoni_s         1   1/12/2015
# 12206             12207      5361   pepperoni_s         1   3/31/2015
# 20405             20406      8961   pepperoni_s         1   5/30/2015
# ...                 ...       ...           ...       ...         ...
# 18317             18318      8040    thai_ckn_l         3   5/15/2015
# 37638             37639     16619  prsc_argla_l         3   10/8/2015
# 183                 184        78  spicy_ital_l         3    1/2/2015
# 38819             38820     17112     bbq_ckn_l         3  10/17/2015
# 35496             35497     15674    cali_ckn_l         4   9/19/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values('pizza_size')
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 37229             37230     16437     hawaiian_l         1   10/3/2015
# 34642             34643     15291   napolitana_l         1   9/12/2015
# 15754             15755      6916  classic_dlx_l         1   4/26/2015
# 34643             34644     15291  pep_msh_pep_l         1   9/12/2015
# 34644             34645     15291   veggie_veg_l         1   9/12/2015
# ...                 ...       ...            ...       ...         ...
# 43040             43041     18919  the_greek_xxl         1  11/19/2015
# 19441             19442      8546  the_greek_xxl         1   5/23/2015
# 47489             47490     20866  the_greek_xxl         1  12/20/2015
# 17114             17115      7528  the_greek_xxl         1    5/7/2015
# 9844               9845      4307  the_greek_xxl         1   3/14/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values('pizza_name')
# Out:
#        order_details_id  order_id      pizza_id  quantity  order_date  \
# 48619             48620     21350     bbq_ckn_s         1  12/31/2015
# 40718             40719     17943     bbq_ckn_m         1   11/2/2015
# 40717             40718     17943     bbq_ckn_l         1   11/2/2015
# 12587             12588      5531     bbq_ckn_l         1    4/3/2015
# 40708             40709     17940     bbq_ckn_l         1   11/2/2015
# ...                 ...       ...           ...       ...         ...
# 31602             31603     13953  veggie_veg_m         1   8/21/2015
# 8590               8591      3765  veggie_veg_s         1    3/5/2015
# 23331             23332     10260  veggie_veg_m         1   6/21/2015
# 45908             45909     20157  veggie_veg_l         1   12/9/2015
# 31303             31304     13819  veggie_veg_s         1   8/18/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values('unit_price',ascending=False, inplace=True)

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 22903             22904     10075  the_greek_xxl         1   6/18/2015
# 13779             13780      6038  the_greek_xxl         1   4/12/2015
# 5901               5902      2614  the_greek_xxl         1   2/13/2015
# 14029             14030      6150  the_greek_xxl         1   4/13/2015
# 41182             41183     18139  the_greek_xxl         1   11/5/2015
# ...                 ...       ...            ...       ...         ...
# 39654             39655     17464    pepperoni_s         1  10/24/2015
# 2252               2253      1003    pepperoni_s         1   1/17/2015
# 46395             46396     20379    pepperoni_s         1  12/12/2015
# 35242             35243     15562    pepperoni_s         1   9/17/2015
# 3771               3772      1675    pepperoni_s         1   1/29/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values(['unit_price','total_price'])
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 36424             36425     16084    pepperoni_s         1  9/28/2015
# 31305             31306     13820    pepperoni_s         1  8/18/2015
# 45196             45197     19865    pepperoni_s         1  12/4/2015
# 29447             29448     13010    pepperoni_s         1   8/5/2015
# 29450             29451     13011    pepperoni_s         1   8/5/2015
# ...                 ...       ...            ...       ...        ...
# 30207             30208     13341  the_greek_xxl         1  8/11/2015
# 10875             10876      4761  the_greek_xxl         1  3/21/2015
# 17114             17115      7528  the_greek_xxl         1   5/7/2015
# 23298             23299     10243  the_greek_xxl         1  6/21/2015
# 36037             36038     15911  the_greek_xxl         1  9/23/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.sort_values(['unit_price','total_price'],ascending=[True,False])
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 890                 891       392    pepperoni_s         2    1/7/2015
# 11035             11036      4836    pepperoni_s         2   3/23/2015
# 39865             39866     17546    pepperoni_s         2  10/25/2015
# 4507               4508      2000    pepperoni_s         2    2/3/2015
# 7318               7319      3226    pepperoni_s         2   2/24/2015
# ...                 ...       ...            ...       ...         ...
# 30207             30208     13341  the_greek_xxl         1   8/11/2015
# 10875             10876      4761  the_greek_xxl         1   3/21/2015
# 17114             17115      7528  the_greek_xxl         1    5/7/2015
# 23298             23299     10243  the_greek_xxl         1   6/21/2015
# 36037             36038     15911  the_greek_xxl         1   9/23/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.drop_duplicates(subset=['total_price'])
# Out:
#        order_details_id  order_id        pizza_id  quantity  order_date  \
# 22903             22904     10075   the_greek_xxl         1   6/18/2015
# 27333             27334     12028    the_greek_xl         1   7/20/2015
# 21607             21608      9483    the_greek_xl         2    6/8/2015
# 43115             43116     18954    brie_carre_s         1  11/20/2015
# 17159             17160      7550    brie_carre_s         2    5/7/2015
# 1594               1595       712   ital_veggie_l         1   1/12/2015
# 15607             15608      6839    spicy_ital_l         1   4/25/2015
# 41691             41692     18342    southw_ckn_l         2   11/9/2015
# 18317             18318      8040      thai_ckn_l         3   5/15/2015
# 35496             35497     15674      cali_ckn_l         4   9/19/2015
# 45867             45868     20134     the_greek_l         1   12/8/2015
# 13822             13823      6055   ital_cpcllo_l         2   4/12/2015
# ...

# %%
df.drop_duplicates(subset=['unit_price']).shape
# Out:
# (25, 12)

# %%
df.drop_duplicates(subset=['order_id'])
# Out:
#        order_details_id  order_id       pizza_id  quantity order_date  \
# 22903             22904     10075  the_greek_xxl         1  6/18/2015
# 13779             13780      6038  the_greek_xxl         1  4/12/2015
# 5901               5902      2614  the_greek_xxl         1  2/13/2015
# 14029             14030      6150  the_greek_xxl         1  4/13/2015
# 41182             41183     18139  the_greek_xxl         1  11/5/2015
# ...                 ...       ...            ...       ...        ...
# 11941             11942      5246    pepperoni_s         1  3/29/2015
# 23755             23756     10449    pepperoni_s         1  6/24/2015
# 11952             11953      5250    pepperoni_s         1  3/30/2015
# 31956             31957     14106    pepperoni_s         1  8/23/2015
# 15914             15915      6996    pepperoni_s         1  4/27/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.drop_duplicates(subset=['pizza_id','order_id'])
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 22903             22904     10075  the_greek_xxl         1   6/18/2015
# 13779             13780      6038  the_greek_xxl         1   4/12/2015
# 5901               5902      2614  the_greek_xxl         1   2/13/2015
# 14029             14030      6150  the_greek_xxl         1   4/13/2015
# 41182             41183     18139  the_greek_xxl         1   11/5/2015
# ...                 ...       ...            ...       ...         ...
# 39654             39655     17464    pepperoni_s         1  10/24/2015
# 2252               2253      1003    pepperoni_s         1   1/17/2015
# 46395             46396     20379    pepperoni_s         1  12/12/2015
# 35242             35243     15562    pepperoni_s         1   9/17/2015
# 3771               3772      1675    pepperoni_s         1   1/29/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
r
