# %%
print("Kaushik Chaudhari")
# Out:
# Kaushik Chaudhari

# %%
a="Kaushik"
print(a)
# Out:
# Kaushik

# %%
a=23
b=45
print(a)
print(b)
# Out:
# 23
# 45

# %%
x,y,z="Orange","Apple","PineApple"
print(x,y,z)
# Out:
# Orange Apple PineApple

# %%
A=1
B=2.3
C= 2 + 4j
#print (C)
print(type(A))
print(type(B))
type(C)
# Out:
# <class 'int'>
# <class 'float'>
# complex

# %%
A="Hello World"
print(A[1:10])
print(A[1:4])
print(A[-4:-1])
A.replace("Hello","Hi")
# Out:
# ello Worl
# ell
# orl
# 'Hi World'

# %%
A="Hi"
B="Kaushik"
print(A+B)
print(A+" "+B)
# Out:
# HiKaushik
# Hi Kaushik

# %%
A=10
B=20
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A**B)
print(A^B)
print(A==B)
print(A<B)
print(A>B)
print(A!=B)
# Out:
# 30
# -10
# 200
# 0.5
# 100000000000000000000
# 30
# False
# True
# False
# True
